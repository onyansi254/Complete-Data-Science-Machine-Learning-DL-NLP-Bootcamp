# %% [markdown]
# # 📌 DISCRETE PROBABILITY DISTRIBUTIONS
#
# ---
#
# ## ✅ **1. Bernoulli Distribution**
#
# * **Scenario:** Single trial with 2 outcomes (success/failure).
# * **PMF:**
#
# $$
# P(X=x)=p^x(1-p)^{1-x},\;x\in\{0,1\}
# $$
#
# * **Mean:** $E[X]=p$
# * **Variance:** $\mathrm{Var}(X)=p(1-p)$
#
# **Example Q:** A coin has $P(\text{Heads})=0.7$. What is $P(\text{Heads})$?
#
# $$
# P(X=1)=0.7
# $$
#
# ---
#
# ## ✅ **2. Binomial Distribution**
#
# * **Scenario:** Number of successes in **n independent Bernoulli trials**.
# * **PMF:**
#
# $$
# P(X=k)=\binom{n}{k}p^k(1-p)^{n-k},\;k=0,1,\dots,n
# $$
#
# * **Mean:** $E[X]=np$
# * **Variance:** $\mathrm{Var}(X)=np(1-p)$
#
# **Example Q:** Toss a fair coin $3$ times. What’s $P(\text{exactly 2 heads})$?
#
# $$
# P(X=2)=\binom{3}{2}(0.5)^2(0.5)=0.375
# $$
#
# ---
#
# ## ✅ **3. Geometric Distribution**
#
# * **Scenario:** Number of trials until the **first success**.
# * **PMF:**
#
# $$
# P(X=k)=(1-p)^{k-1}p,\;k=1,2,\dots
# $$
#
# * **Mean:** $E[X]=\frac{1}{p}$
# * **Variance:** $\mathrm{Var}(X)=\frac{1-p}{p^2}$
#
# **Example Q:** Player scores with $p=0.4$. What’s $P(\text{success on 3rd trial})$?
#
# $$
# P(X=3)=0.6^2\cdot0.4=0.144
# $$
#
# ---
#
# ## ✅ **4. Negative Binomial Distribution**
#
# * **Scenario:** Number of trials needed for **r successes**.
# * **PMF:**
#
# $$
# P(X=k)=\binom{k-1}{r-1}p^r(1-p)^{k-r},\;k=r,r+1,\dots
# $$
#
# * **Mean:** $E[X]=\frac{r}{p}$
# * **Variance:** $\mathrm{Var}(X)=\frac{r(1-p)}{p^2}$
#
# **Example Q:** Coin with $p=0.5$. What’s $P(\text{3rd head on 5th toss})$?
#
# $$
# P(X=5)=\binom{4}{2}(0.5)^3(0.5)^2=0.15625
# $$
#
# ---
#
# ## ✅ **5. Poisson Distribution**
#
# * **Scenario:** Number of events in fixed time/space with rate λ.
# * **PMF:**
#
# $$
# P(X=k)=\frac{e^{-λ}λ^k}{k!},\;k=0,1,2,\dots
# $$
#
# * **Mean/Variance:** $E[X]=\mathrm{Var}(X)=λ$
#
# **Example Q:** Calls arrive at 3/min. $P(\text{exactly 2 calls in a min})$?
#
# $$
# P(X=2)=\frac{e^{-3}3^2}{2!}\approx0.224
# $$
#
# ---
#
# ## ✅ **6. Logarithmic (Log-Series) Distribution**
#
# * **Scenario:** Rare event counts.
# * **PMF:**
#
# $$
# P(X=k)=-\frac{1}{\ln(1-p)}\frac{p^k}{k},\;k\ge1
# $$
#
# ---
#
# ---
#
# # 📌 CONTINUOUS PROBABILITY DISTRIBUTIONS
#
# ---
#
# ## ✅ **7. Uniform Distribution**
#
# * **PDF:**
#
# $$
# f(x)=\frac{1}{b-a},\;a\le x\le b
# $$
#
# * **Mean:** $\frac{a+b}{2}$
# * **Variance:** $\frac{(b-a)^2}{12}$
#
# ---
#
# ## ✅ **8. Normal Distribution**
#
# * **PDF:**
#
# $$
# f(x)=\frac{1}{σ\sqrt{2π}}e^{-\frac{(x-μ)^2}{2σ^2}}
# $$
#
# * **Mean:** μ, **Variance:** σ²
#
# **Example Q:** IQ\~N(100,15²). $P(\text{IQ>120})$? → standardize Z-score.
#
# ---
#
# ## ✅ **9. Exponential Distribution**
#
# * **Scenario:** Time between Poisson events.
# * **PDF:**
#
# $$
# f(x)=λe^{-λx},\;x≥0
# $$
#
# * **Mean:** $1/λ$, **Variance:** $1/λ^2$
#
# **Example Q:** Avg wait=10min (λ=0.1). $P(\text{wait<5})=1-e^{-0.5}=0.393$.
#
# ---
#
# ## ✅ **10. Gamma Distribution**
#
# * **PDF:**
#
# $$
# f(x;k,θ)=\frac{x^{k-1}e^{-x/θ}}{θ^kΓ(k)},\;x>0
# $$
#
# * **Mean:** $kθ$, **Var:** $kθ^2$
#
# ---
#
# ## ✅ **11. Beta Distribution**
#
# * **PDF:**
#
# $$
# f(x;α,β)=\frac{Γ(α+β)}{Γ(α)Γ(β)}x^{α-1}(1-x)^{β-1},\;0<x<1
# $$
#
# ---
#
# ## ✅ **12. Pareto (Power-Law) Distribution**
#
# * **PDF:**
#
# $$
# f(x)=αx_m^αx^{-(α+1)},\;x≥x_m
# $$
#
# ---
#
# ## ✅ **13. Log-Normal Distribution**
#
# * **PDF:**
#
# $$
# f(x)=\frac{1}{xσ√{2π}}\exp\!\left(-\frac{(\ln x-μ)^2}{2σ^2}\right),\;x>0
# $$
#
# * **Mean:** $e^{μ+σ^2/2}$
#
# ---
#
# ## ✅ **14. Weibull Distribution**
#
# * **PDF:**
#
# $$
# f(x;k,λ)=\frac{k}{λ}\left(\frac{x}{λ}\right)^{k-1}e^{-(x/λ)^k},\;x≥0
# $$
#
# * **Used in reliability/failure time.**
#
# ---
#
# ## ✅ **15. Cauchy Distribution**
#
# * **PDF:**
#
# $$
# f(x;x_0,γ)=\frac{1}{πγ\left[1+\left(\frac{x-x_0}{γ}\right)^2\right]}
# $$
#
# ---
#
# ---
#
# # 📌 SUMMARY TABLE
#
# | Distribution  | Type       | PMF/PDF                          | Mean    | Var                 |
# | ------------- | ---------- | -------------------------------- | ------- | ------------------- |
# | Bernoulli     | Discrete   | $p^x(1-p)^{1-x}$                 | p       | p(1-p)              |
# | Binomial      | Discrete   | $\binom{n}{k}p^k(1-p)^{n-k}$     | np      | np(1-p)             |
# | Geometric     | Discrete   | (1-p)^{k-1}p                     | 1/p     | (1-p)/p²            |
# | Neg. Binomial | Discrete   | $\binom{k-1}{r-1}p^r(1-p)^{k-r}$ | r/p     | r(1-p)/p²           |
# | Poisson       | Discrete   | e^{-λ}λ^k/k!                     | λ       | λ                   |
# | Normal        | Continuous | bell curve                       | μ       | σ²                  |
# | Exponential   | Continuous | λe^{-λx}                         | 1/λ     | 1/λ²                |
# | Gamma         | Continuous | x^{k-1}e^{-x/θ}/(θ^kΓ(k))        | kθ      | kθ²                 |
# | Beta          | Continuous | x^{α-1}(1-x)^{β-1}               | α/(α+β) | αβ/\[(α+β)²(α+β+1)] |
#
# ---
#
# # 📌 PRACTICE QUESTIONS
#
# 1️⃣ **Bernoulli:**
# A machine is defective with p=0.1. What’s the probability it works?
#
# 2️⃣ **Binomial:**
# Guess 5 MCQs with p=0.25. What’s P(2 correct)?
#
# 3️⃣ **Geometric:**
# Roll dice until a 6. What’s P(4th roll is first 6)?
#
# 4️⃣ **Negative Binomial:**
# Need 3 heads. What’s P(3rd head on 5th toss)?
#
# 5️⃣ **Poisson:**
# Website gets λ=4 visits/hr. What’s P(no visits in an hour)?
#
# 6️⃣ **Exponential:**
# Bus avg every 10min. What’s P(wait<5min)?
#
# 7️⃣ **Normal:**
# IQ\~N(100,15²). What’s P(IQ>120)?
#
# 8️⃣ **Pareto:**
# α=2,xm=1000. P(X>4000)?
