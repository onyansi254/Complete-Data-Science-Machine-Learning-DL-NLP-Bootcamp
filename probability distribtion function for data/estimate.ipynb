# %% [markdown]
# There are **two main categories of estimates**:
#
# 1. **Point Estimates**
# 2. **Interval Estimates**
#
# Let’s break it down.
#
# ---
#
# ## ✅ 1. What is an Estimate?
#
# * An **estimate** is a value or range of values derived from sample data to **approximate an unknown population parameter** (like mean, variance, or proportion).
# * For example:
#
#   * You can’t measure the **true average height** of all adults in Kenya, so you take a sample and **estimate** the mean.
#
# ---
#
# ## ✅ 2. Types of Estimates
#
# ### **A) Point Estimate**
#
# * A **single number** that serves as the best guess for the population parameter.
# * Example:
#
#   * Sample mean ($\bar{x}$) is a **point estimate** of the population mean ($\mu$).
#   * Sample proportion ($\hat{p}$) is a **point estimate** of the population proportion ($p$).
#
# 📌 **Properties of a Good Point Estimator**
#
# * **Unbiased** → Expected value equals the true parameter
# * **Consistent** → Improves with larger samples
# * **Efficient** → Has the smallest variance among all unbiased estimators
#
# ---
#
# ### **B) Interval Estimate (Confidence Interval)**
#
# * Instead of giving one number, you give a **range** likely to contain the true parameter.
# * Example:
#
#   * You might say: *The average height is **170 cm ± 2 cm** with 95% confidence.*
#
# **Formula for a Confidence Interval (CI):**
#
# $$
# \text{Point Estimate} \pm \text{Margin of Error}
# $$
#
# * Margin of Error depends on:
#
#   * Confidence level (e.g. 95%)
#   * Standard error of the sample
#
# Example for population mean (when σ is known):
#
# $$
# \bar{x} \pm Z_{\alpha/2} \frac{\sigma}{\sqrt{n}}
# $$
#
# ---
#
# ### **C) Other Special Types**
#
# 1. **Maximum Likelihood Estimate (MLE)**
#
#    * Chooses the parameter value that **maximizes the likelihood** of observing the given data.
# 2. **Bayesian Estimate**
#
#    * Uses **prior knowledge** + sample data to estimate parameters.
#
# ---
#
# ## ✅ 3. Example
#
# * You want to estimate the **average exam score** of students in a university.
#
# * You take a sample of **50 students**, find the **sample mean = 75**, and **sample standard deviation = 10**.
#
# * **Point Estimate:**
#   $\hat{\mu} = 75$
#
# * **95% Confidence Interval:**
#
#   $$
#   75 \pm 1.96 \left( \frac{10}{\sqrt{50}} \right) = 75 \pm 2.77
#   $$
#
#   So the **CI** is **(72.23, 77.77)**.
#
# ---
#
# ## ✅ Quick Summary
#
# | **Type**              | **Definition**                                         | **Example**                                          |
# | --------------------- | ------------------------------------------------------ | ---------------------------------------------------- |
# | **Point Estimate**    | A single best guess for the parameter                  | Sample mean $\bar{x}$ as estimate of population mean |
# | **Interval Estimate** | A range of values likely containing the true parameter | Confidence interval for mean                         |
# | **MLE**               | Value that maximizes likelihood of observed data       | Estimating λ in Poisson                              |
# | **Bayesian Estimate** | Combines prior info + data                             | Bayesian mean estimate                               |

# %% [markdown]
# ## ✅ 1. POINT ESTIMATES
#
# A **point estimate** is a **single best guess** for a population parameter based on sample data.
#
# ---
#
# ### **1.1 Common Point Estimators**
#
# | **Population Parameter**         | **Point Estimator**           | **Formula**                                |
# | -------------------------------- | ----------------------------- | ------------------------------------------ |
# | Population mean ($\mu$)          | Sample mean ($\bar{x}$)       | $\bar{x} = \frac{\sum x_i}{n}$             |
# | Population proportion ($p$)      | Sample proportion ($\hat{p}$) | $\hat{p} = \frac{\text{# successes}}{n}$   |
# | Population variance ($\sigma^2$) | Sample variance ($s^2$)       | $s^2 = \frac{\sum (x_i - \bar{x})^2}{n-1}$ |
#
# ---
#
# ### ✅ **Example 1: Point Estimate of Mean**
#
# * Suppose you take a sample of **5 students’ marks**:
#
#   $$
#   60, 70, 80, 75, 65
#   $$
#
# * Sample mean:
#
#   $$
#   \bar{x} = \frac{60 + 70 + 80 + 75 + 65}{5} = 70
#   $$
#
# So, the **point estimate** of the population mean is **70**.
#
# ---
#
# ## ✅ 2. INTERVAL ESTIMATES (CONFIDENCE INTERVALS)
#
# Instead of one value, we give a **range** that is likely to contain the population parameter.
#
# ---
#
# ### **2.1 Confidence Interval for the Population Mean**
#
# There are **two cases**:
#
# 1. **σ known** → Use **Z-distribution**
#
#    $$
#    CI = \bar{x} \pm Z_{\alpha/2} \left(\frac{\sigma}{\sqrt{n}}\right)
#    $$
#
# 2. **σ unknown** → Use **t-distribution**
#
#    $$
#    CI = \bar{x} \pm t_{\alpha/2, n-1} \left(\frac{s}{\sqrt{n}}\right)
#    $$
#
# Where:
#
# * $Z_{\alpha/2}$ = critical value from standard normal
# * $t_{\alpha/2, n-1}$ = critical value from t-table
#
# ---
#
# ### ✅ **Example 2: CI for Mean (σ known)**
#
# * Sample mean $\bar{x} = 75$
# * Population std. dev. σ = 10
# * Sample size $n = 50$
# * Confidence level = 95% → $Z_{0.025} = 1.96$
#
# $$
# CI = 75 \pm 1.96 \left( \frac{10}{\sqrt{50}} \right)
# $$
#
# * Standard error = $\frac{10}{\sqrt{50}} = 1.414$
# * Margin of error = $1.96 × 1.414 ≈ 2.77$
#
# ✅ So the 95% CI is **(72.23, 77.77)**.
#
# ---
#
# ### **2.2 Confidence Interval for Proportion**
#
# $$
# CI = \hat{p} \pm Z_{\alpha/2} \sqrt{\frac{\hat{p}(1 - \hat{p})}{n}}
# $$
#
# ✅ **Example 3: CI for Proportion**
#
# * In a sample of 200 voters, 120 support a candidate.
# * Sample proportion $\hat{p} = \frac{120}{200} = 0.6$
# * Confidence level 95% → $Z_{0.025} = 1.96$
#
# $$
# SE = \sqrt{\frac{0.6(1 - 0.6)}{200}} = \sqrt{\frac{0.24}{200}} = 0.0346
# $$
#
# $$
# CI = 0.6 \pm 1.96 × 0.0346 = 0.6 \pm 0.0678
# $$
#
# ✅ So the 95% CI is **(0.532, 0.668)**.
#
# ---
#
# ## ✅ 3. OTHER ESTIMATES
#
# ---
#
# ### **3.1 Maximum Likelihood Estimate (MLE)**
#
# * MLE finds the parameter value that **maximizes the likelihood function**.
# * Example: For a **Bernoulli distribution**, the MLE of $p$ is just $\hat{p} = \frac{\text{successes}}{n}$.
#
# ---
#
# ### **3.2 Bayesian Estimate**
#
# * Bayesian estimation **combines prior belief (prior distribution)** with **sample data** to get a **posterior estimate**.
# * Used when you have **prior knowledge**.
#
# ---
#
# ## ✅ 4. QUICK SUMMARY CHART
#
# | **Type of Estimate**        | **Definition**                                                | **Formula / Example**            |
# | --------------------------- | ------------------------------------------------------------- | -------------------------------- |
# | **Point Estimate**          | Single value estimate of parameter                            | $\bar{x}$ for μ, $\hat{p}$ for p |
# | **Interval Estimate**       | Range likely to contain true parameter                        | CI = Point ± Margin of Error     |
# | **CI for Mean (σ known)**   | $\bar{x} \pm Z_{\alpha/2}\frac{\sigma}{\sqrt{n}}$             | e.g. (72.2, 77.8)                |
# | **CI for Mean (σ unknown)** | $\bar{x} \pm t_{\alpha/2,n-1}\frac{s}{\sqrt{n}}$              | uses t-distribution              |
# | **CI for Proportion**       | $\hat{p} \pm Z_{\alpha/2}\sqrt{\frac{\hat{p}(1-\hat{p})}{n}}$ | e.g. (0.53, 0.67)                |
# | **MLE**                     | Parameter maximizing likelihood                               | For Bernoulli, MLE = $\hat{p}$   |
# | **Bayesian**                | Uses prior + data                                             | Posterior mean                   |
#
# ---
#
# ## ✅ 5. RELATIONSHIP BETWEEN POINT & INTERVAL ESTIMATE
#
# * Point estimate is **best single guess**
# * Interval estimate is **point estimate ± margin of error**
#
# Think of it like **shooting an arrow**:
#
# * Point = **exact hit**
# * Interval = **safe range where it likely falls**
#
# ---
